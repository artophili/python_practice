# %%
def rev_n(n):
    rev = 0
    if n == 0:
        return rev

    rev = (rev * 10) + (n % 10)
    return rev_n(n/10)

rev_n(1234)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[11], line 8
#       5     rev = (rev * 10) + (n % 10)
#       6     return rev_n(n/10)
# ----> 8 rev_n(1234)
#
# Cell In[11], line 5, in rev_n(n)
#       2 if n == 0:
#       3     return rev
# ----> 5 rev = (rev * 10) + (n % 10)
#       6 return rev_n(n/10)
#
# UnboundLocalError: cannot access local variable 'rev' where it is not associated with a value
